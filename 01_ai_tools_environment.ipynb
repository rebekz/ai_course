# %% [markdown]
# # Introduction to Artificial Intelligence, Tools and Environments
#
# This notebook provides a brief introduction to AI and demonstrates how to work with tools such as Python and Jupyter Notebooks. We will also highlight the Google Colab environment, which is a popular cloud-based platform for running Python code without local installations.

# %% [markdown]
# ## Overview
#
# In this notebook you will learn:
#
# - **Fundamental AI Concepts:** A brief introduction to AI.
# - **Tools & Environments:** An overview of Python, Jupyter Notebooks, and Google Colab.
# - **Google Colab Features:** How to create a notebook, run code, use Markdown, access external files, and utilize GPU/TPU acceleration.
#
# Let's start by exploring the Google Colab environment.

# %% [markdown]
# ## Google Colab Overview
#
# Google Colab is a cloud-based Jupyter Notebook environment provided by Google. Its key advantages include:
#
# - **Free access to GPUs/TPUs:** Enhance your AI computations without local hardware constraints.
# - **Cloud-based and easy to share:** Simply save notebooks in Google Drive and share them with collaborators.
# - **No local installation required:** Write and run Python code directly from your browser.
#
# Below is a simple code cell demonstrating a welcome message in Google Colab.

# %%
print("Hello, Google Colab!")
# Out:
# Hello, Google Colab!

# %% [markdown]
# ## Using Markdown in Your Notebook
#
# Markdown cells allow you to add formatted text, headings, lists, and more. For example, you can use the following Markdown syntax:
#
# ```markdown
# # Heading 1
# ## Heading 2
# **Bold text** and *italic text*
# - List item 1
# - List item 2
# ```
#
# Try creating your own Markdown cell to document your work.

# %% [markdown]
# ## Simple Data Analysis Example
#
# In this section, we will create a small dataset, visualize it using a bar chart, and calculate the average of the values. This exercise demonstrates the integration of Python code and data visualization tools like `pandas` and `matplotlib`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data: Student names and their grades
data = {
    'Mahasiswa': ['A', 'B', 'C', 'D', 'E'],
    'Nilai': [78, 85, 92, 70, 88]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Plotting the data as a bar chart
df.plot(kind='bar', x='Mahasiswa', y='Nilai', legend=False)
plt.xlabel('Mahasiswa')
plt.ylabel('Nilai')
plt.title('Nilai Mahasiswa')
plt.show()
# Out:
#   Mahasiswa  Nilai
# 0         A     78
# 1         B     85
# 2         C     92
# 3         D     70
# 4         E     88

# %% [markdown]
# ## Calculating the Average Grade
#
# Now, let's compute the average grade using the DataFrame we created. Completing this exercise reinforces the use of Python for data analysis.

# %%
# Calculate average grade
rata_rata = df['Nilai'].mean()
print(f"Rata-rata Nilai Mahasiswa: {rata_rata}")
# Out:
# Rata-rata Nilai Mahasiswa: 82.6

# %% [markdown]
# ## Additional Google Colab Features
#
# ### Mounting Google Drive
#
# To access files stored in your Google Drive, run the following code in a code cell:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# ### Installing Additional Libraries
#
# If you need to install additional Python libraries, use the `!pip install` command. For example:
#
# ```python
# !pip install numpy pandas matplotlib
# ```
#
# ### Using Magic Commands
#
# Google Colab supports magic commands, such as:
#
# - `!ls` to list files in the current directory.
# - `%timeit` to measure code execution time.
# - `%matplotlib inline` to display plots inline in the notebook.
#
# These features enhance your productivity and streamline your AI experimentation.

# %% [markdown]
# # Advanced AI Tools and Environments
#
# Let's explore more advanced AI tools and environments that are commonly used in the field.

# %% [markdown]
# ## 1. TensorFlow and Keras
#
# TensorFlow is an open-source machine learning framework developed by Google. Keras is a high-level neural networks API that runs on top of TensorFlow. Together, they provide powerful tools for building and training neural networks.
#
# Here's a simple example of creating a neural network with TensorFlow and Keras:

# %%
# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras

# Print versions
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")

# Create a simple neural network
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# TensorFlow version: 2.18.0
# Keras version: 3.8.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ...

# %% [markdown]
# ## 2. PyTorch
#
# PyTorch is another popular open-source machine learning library developed by Facebook's AI Research lab. It's known for its flexibility and dynamic computation graph.
#
# Here's a simple example of creating a neural network with PyTorch:

# %%
# Import PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# Print version
print(f"PyTorch version: {torch.__version__}")

# Define a simple neural network
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 10)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# Create an instance of the network
model = SimpleNet()
print(model)
# Out:
# PyTorch version: 2.5.1+cu124
# SimpleNet(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ## 3. Scikit-learn
#
# Scikit-learn is a simple and efficient tool for data mining and data analysis. It's built on NumPy, SciPy, and matplotlib, and is designed to interoperate with these libraries.
#
# Here's an example of using scikit-learn for a simple classification task:

# %%
# Import scikit-learn
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split

# Load the digits dataset
digits = datasets.load_digits()

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    digits.data, digits.target, test_size=0.2, random_state=42)

# Create a classifier: Support Vector Classifier
clf = svm.SVC(gamma=0.001)

# Train the model
clf.fit(X_train, y_train)

# Predict the value of the test set
y_pred = clf.predict(X_test)

# Print the classification report
print("Classification report:\n",
      metrics.classification_report(y_test, y_pred))

# Display some sample digits
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary')
    ax.set_title(f"Label: {digits.target[i]}")
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00        28
#            2       1.00      1.00      1.00        33
#            3       1.00      0.97      0.99        34
#            4       1.00      1.00      1.00        46
#            5       0.98      0.98      0.98        47
#            6       0.97      1.00      0.99        35
#            7       0.97      0.97      0.97        34
#            8       1.00      1.00      1.00        30
#            9       0.97      0.97      0.97        40
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %% [markdown]
# ## 4. Natural Language Processing with NLTK and spaCy
#
# Natural Language Processing (NLP) is a field of AI that focuses on the interaction between computers and human language. NLTK (Natural Language Toolkit) and spaCy are popular libraries for NLP tasks.
#
# Here's an example using NLTK for basic text processing:

# %%
# Import NLTK
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Download the 'punkt_tab' resource
nltk.download('punkt_tab')  # This line is added
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Sample text
text = "Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language."

# Tokenize the text
tokens = word_tokenize(text)
print("Tokens:", tokens[:10], "...")

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("\nFiltered tokens (stopwords removed):", filtered_tokens[:10], "...")

# Lemmatize words
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("\nLemmatized words:", lemmatized[:10], "...")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens: ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'subfield', 'of'] ...
#
# Filtered tokens (stopwords removed): ['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer'] ...
#
# Lemmatized words: ['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer'] ...

# %% [markdown]
# ## 5. Computer Vision with OpenCV
#
# OpenCV (Open Source Computer Vision Library) is an open-source computer vision and machine learning software library. It's widely used for image and video processing tasks.
#
# Here's a simple example of using OpenCV for image processing:

# %%
# Import OpenCV
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Create a simple image
image = np.zeros((200, 200, 3), np.uint8)
image = cv2.rectangle(image, (50, 50), (150, 150), (0, 255, 0), -1)
image = cv2.circle(image, (100, 100), 30, (0, 0, 255), -1)

# Convert BGR to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Apply some filters
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 30, 100)
blurred = cv2.GaussianBlur(image_rgb, (15, 15), 0)

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(221), plt.imshow(image_rgb)
plt.title('Original Image'), plt.axis('off')

plt.subplot(222), plt.imshow(gray, cmap='gray')
plt.title('Grayscale'), plt.axis('off')

plt.subplot(223), plt.imshow(edges, cmap='gray')
plt.title('Edge Detection'), plt.axis('off')

plt.subplot(224), plt.imshow(blurred)
plt.title('Blurred'), plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Cloud-based AI Services
#
# Many cloud providers offer AI services that can be easily integrated into your applications. Here are some examples:
#
# 1. **Google Cloud AI Platform**
#    - AutoML for custom model training
#    - Pre-trained APIs for vision, language, and speech
#    - AI Infrastructure for training and serving models
#
# 2. **Amazon Web Services (AWS) AI Services**
#    - Amazon SageMaker for building, training, and deploying ML models
#    - Amazon Rekognition for image and video analysis
#    - Amazon Comprehend for natural language processing
#
# 3. **Microsoft Azure AI**
#    - Azure Machine Learning for end-to-end ML lifecycle
#    - Cognitive Services for vision, speech, language, and decision APIs
#    - Azure Bot Service for intelligent bots
#
# These services provide APIs that can be called from your code, allowing you to leverage powerful AI capabilities without having to build everything from scratch.

# %% [markdown]
# ## 9. Interactive Visualization Tools
#
# Interactive visualizations can help you better understand your data and models. Here's an example using Plotly:

# %%
# Import Plotly
import plotly.express as px
import numpy as np

# Generate some sample data
np.random.seed(42)
x = np.random.normal(0, 1, 1000)
y = x * 0.8 + np.random.normal(0, 0.5, 1000)
z = x * 0.3 + y * 0.6 + np.random.normal(0, 0.3, 1000)

# Create a 3D scatter plot
fig = px.scatter_3d(x=x, y=y, z=z, color=z, opacity=0.7,
                    title="3D Scatter Plot with Plotly")

# Update layout
fig.update_layout(scene=dict(xaxis_title='X',
                             yaxis_title='Y',
                             zaxis_title='Z'),
                  width=800, height=600)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 10. Version Control with Git
#
# Version control is essential for AI projects, especially when collaborating with others. Git is the most widely used version control system.
#
# Here are some basic Git commands you can run in a notebook cell:
#
# ```python
# # Initialize a Git repository
# !git init
#
# # Check status
# !git status
#
# # Add files to staging
# !git add .
#
# # Commit changes
# !git commit -m "Initial commit"
#
# # Create a branch
# !git branch feature-branch
#
# # Switch to a branch
# !git checkout feature-branch
# ```
#
# Git integration with platforms like GitHub, GitLab, or Bitbucket allows for easy collaboration and code sharing.

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrated:
#
# - An introduction to Artificial Intelligence and its fundamental concepts.
# - How to use Jupyter Notebooks and Google Colab for running Python code.
# - Basic data analysis using `pandas` and data visualization using `matplotlib`.
#
# Feel free to expand on these examples and explore more advanced AI techniques and tools. Happy coding!
